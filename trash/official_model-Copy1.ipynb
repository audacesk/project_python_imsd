# %% [markdown]
# # Etape I: Import des packages nécessaires

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
from bs4 import BeautifulSoup
from requests import get
from tqdm import tqdm
import urllib

# %% [markdown]
# # Créer une fonction permettant d'automatiser le scrap par la suite

# %%
def y_combinator_scraper(url_user):
    
    '''Appeler l\'URL à scraper '''
    url = url_user
    response = get(url)
    
    '''Lancer une session BeautifulSoup, localiser puis stocker l'adresse de localisaiton du contenu de la page'''
    soup = BeautifulSoup(response.text, 'html.parser')    
    my_table = soup.find('table','table')
    
    ''' Initialisation des listes que nous rempliront par la suite '''
    noms = []
    batch = []
    categories = []
    descriptions = []
    exit_value = []
    #images = []

    '''Répertorier les emplacements des éléments recherchés'''
    names = my_table.find_all('a')
    batches = my_table.find_all('td', 'd-none d-md-table-cell')[0::2]
    category = my_table.find_all('td', 'd-none d-md-table-cell')[1::2]
    description = my_table.find_all('td', 'd-none d-md-table-cell ellipsis')
    levee = my_table.find_all('td', 'text-right')
    #image = my_table.find_all('img')
    
    '''Créer une boucle permettant de parcourir l'arborescence de la page html et d'en sortir les informations (ci-dessus)
        pour chaque lignes du classement'''
    #for i in tqdm(my_table):       

    '''Noms'''
    for y in names:       
        nam = y.text.strip()
        noms.append(nam)

    '''Batch'''
    for y in batches:
        bat = y.text
        batch.append(bat)

    '''Catégories'''
    for y in category:
        cat = y.text
        categories.append(cat)

    '''Descriptions'''
    for y in description:
        des = y.text
        descriptions.append(des)

    '''Levée de fonds total'''
    for y in levee:
        lev = y.text
        exit_value.append(lev)

    '''Logo
    for y in image:
        img = y.get('src')
        download_img = get(img)
        images.append(download_img)'''
    print(type(noms[1]))
    print(type(batch[1]))
    print(type(categories[1]))
    print(type(descriptions[1]))
    print(type(exit_value[1]))
    datas = np.column_stack((noms,batch,categories,descriptions,exit_value))
    df = pd.DataFrame(datas, columns=['noms', 'batch', 'categories', 'descriptions', 'exit_value'])
    df.to_excel(excel_writer='ranking11_exit_value.xlsx')

    '''ATTENTION: les images seront à remettre dans le rendu final'''

# %% [markdown]
# # Liste des urls à scrapper

# %%
url_funding = 'https://www.ycdb.co/top-companies/funding'
url_visited = 'https://www.ycdb.co/top-companies/alexa-rank'
url_popular = 'https://www.ycdb.co/top-companies/twitter-followers'
url_authoritative = 'https://www.ycdb.co/top-companies/domain-authority'
url_liked = 'https://www.ycdb.co/top-companies/facebook-likes'
url_upvoted = 'https://www.ycdb.co/top-companies/product-hunt-votes'
url_growing = 'https://www.ycdb.co/top-companies/growth-score'
url_prolific = 'https://www.ycdb.co/top-companies/tweet-count'
url_influential = 'https://www.ycdb.co/top-companies/linkedin-followers'
url_populous = 'https://www.ycdb.co/top-companies/employees'
url_exit_value = 'https://www.ycdb.co/top-companies/exit-value'

urls = [url_funding, url_visited, url_popular]

# %%
y_combinator_scraper(url_exit_value)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# array([['Cruise', 'W14', 'Transport', 'Self-driving cars.', '$1,000.0m'],
#        ['Twitch', 'W07', 'Entertainment', 'Video game live streaming',
#         '$970.0m'],
#        ['PlanGrid', 'W12', 'Real Estate',
#         'We build mobile applications for the construction industry',
#         '$875.0m'],
#        ['Weebly', 'W07', 'Other SaaS',
#         'Web site editing platform.  Over 40M people have launched their business on Weebly and every month 325M people visit a Weebly-made site, or 50% of the US.',
#         '$365.0m'],
#        ['Heroku', 'W08', 'Other SaaS',
#         'Heroku is a multi-language cloud application platform that enables developers to deploy, scale, and manage their applications.',
#         '$250.0m'],
#        ['CoreOS', 'S13', 'Other SaaS',
#         'Enterprise Linux distribution that dramatically improves security and speed of application deployment.',
#         '$250.0m'],
#        ['Omgpop', 'S06', 'Entertainment',
#         'OMGPOP is a leading developer of social games for facebook, iphone and the open web.',
#         '$200.0m'],
#        ['Future Advisor', 'S10', 'Fintech',
#         "The online financial management service for everyone. FutureAdvisor advises and manages all of a customer's financial goals together to help everyone achieve a better financial future.",
#         '$150.0m'],
#        ['Automatic', 'S11', 'Consumer',
#         'Automatic connects your car to the rest of your digital life.',
#         '$115.0m'],
#        ['Disqus', 'S07', 'Dev Tools', 'Add comments to your website.',
#         '$90.0m'],
#        ['Caviar', 'S11', 'Consumer', 'Uber for food.', '$90.0m'],
#        ['Parse', 'S11', 'Dev Tools',
#         'Parse is the easiest way to build apps.', '$85.0m'],
#        ['All Screen', 'W10', 'Other SaaS',
#         'Connecting users with engaging video content across the web. \r\n      \r\n      Acquired by Zealot Networks for $85m',
#         '$85.0m'],
#        ['Smyte', 'W15', 'Other SaaS',
#         'Smyte stops bad actors on social networks and marketplaces.',
#         '$65.0m'],
#        ['Socialcam', 'W12', 'Entertainment',
#         'The easiest way to share videos with friends and family. ',
#         '$60.0m'],
#        ['Hipmunk', 'S10', 'Consumer',
#         'Hipmunk takes the agony out of searching for flights, accommodations, cars, and more.',
#         '$58.0m'],
#        ['Cue', 'W10', 'Consumer',
#         'Cue is a web and mobile app that pulls information from the users’ online accounts to present an overview of their day.',
#         '$50.0m'],
#        ['Cardpool', 'W10', 'Consumer',
#         'Cardpool is a gift card exchange service for individuals to buy, sell and\xa0trade their new\xa0or pre-owned gift cards.',
#         '$50.0m'],
#        ['Xobni', 'S06', 'Other SaaS',
#         "Xobni creates complete and searchable social profiles of a user's contacts that include updates from LinkedIn, Facebook, and Twitter.",
#         '$48.0m'],
#        ['Heyzap', 'W09', 'Entertainment',
#         'Heyzap (acquired by Fyber for $45m in 2016) is one of the largest mobile mediation providers. ',
#         '$45.0m'],
#        ['Loopt', 'S05', 'Entertainment',
#         'Loopt is a mobile application and website that connects people to their community.',
#         '$43.4m'],
#        ['Flutter', 'W12', 'Dev Tools',
#         'Flutter combined computer vision technology with the built-in webcams in laptops, iPads, smartphones and TVs to let users control these devices with gestures, facial expressions, hints and body-language.  Flutter became part of Google in Oct 2013.\r\n      ',
#         '$40.0m'],
#        ['Wufoo', 'W06', 'Other SaaS', 'Online form builder.', '$35.0m'],
#        ['Zencoder', 'W10', 'Other SaaS',
#         'Video Encoding API,\r\n      Open source video player (video.js)',
#         '$30.0m'],
#        ['Cloudkick', 'W09', 'Other SaaS',
#         'Cloudkick is a web-based control hub for cloud servers that offers its users with centralized server monitoring and management tools.',
#         '$30.0m'],
#        ['Mailgun', 'W11', 'Dev Tools', 'Email API service.', '$30.0m'],
#        ['Pebble', 'W11', 'Consumer',
#         'Watch that helps you get shit done and limit the mayhem of notifications',
#         '$23.0m'],
#        ['Perfect Audience', 'S11', 'Other SaaS',
#         'Self-service display advertising for SaaS and online retail.',
#         '$22.8m'],
#        ['Reddit', 'S05', 'Entertainment',
#         'The frontpage of the internet.', '$20.0m'],
#        ['Product Hunt', 'S14', 'Entertainment',
#         'Hacker News for Products', '$20.0m'],
#        ['280 North', 'W08', 'Dev Tools',
#         '280 North is a web software development platform enabling users to build applications through its proprietary tech toolkit, Cappuccino.',
#         '$20.0m'],
#        ['Flightcaster', 'S09', 'Consumer',
#         'FlightCaster offers a service that predicts flight delays, enabling travelers to proactively plan based on the predicted flight delay.',
#         '$15.0m'],
#        ['Movity', 'W10', 'Real Estate',
#         'Real estate data visualization.  Sold to Trulia Dec 2010:\r\n      http://allthingsd.com/20101220/trulia-acquires-movity/',
#         '$15.0m'],
#        ['TalkBin', 'W11', 'Other SaaS', 'Instore feedback.', '$15.0m'],
#        ['Rapportive', 'S10', 'Other SaaS', 'Add profiles to email.',
#         '$15.0m'],
#        ['Omnisio', 'W08', 'Entertainment',
#         'Edit and enhance online video. Acquired by Google in July 2008.',
#         '$15.0m'],
#        ['Meldium', 'W13', 'Other SaaS',
#         'Simple password & identity management for teams. Acquired by LogMeIn in August 2014.',
#         '$15.0m'],
#        ['AdGrok', 'S10', 'Other SaaS',
#         'Easy SEM software. Acquired by Twitter in 2011.', '$10.0m'],
#        ['Mertado', 'W10', 'Other SaaS',
#         'Mertado is an online social shopping platform that allows consumers to discover and buy products from communities they frequently visit.',
#         '$10.0m'],
#        ['Posterous', 'S08', 'Entertainment',
#         'Dead simple blogs by email', '$10.0m'],
#        ['Appjet', 'S07', 'Dev Tools',
#         'AppJet is an online programming tool and web-based text editor for building simple web applications.',
#         '$9.0m'],
#        ['SocialPicks', 'S07', 'Entertainment',
#         'SocialPicks was a platform where stock investors could exchange ideas, track stock performance, and conduct research.  Acquired by Financial Content in 2009.',
#         '$8.0m'],
#        ['Songkick', 'S07', 'Consumer',
#         'Songkick is a ticketing vendor and online database of concerts for music enthusiasts.',
#         '$5.0m'],
#        ['Parakey', 'S05', '',
#         'Parakey is a web-based operating system that synchronizes the user’s desktop environment with the web.',
#         '$5.0m'],
#        ['Divvyshot', 'W09', 'Entertainment',
#         'Divvyshot is a photo-sharing platform that enables users to share full resolution photos with friends.',
#         '$5.0m'],
#        ['Auctomatic', 'W07', 'Consumer',
#         'Auctomatic offers an auction and marketplace management system for individual sellers on the website.',
#         '$5.0m'],
#        ['Snapjoy', 'S11', 'Entertainment', 'Photo library.', '$5.0m'],
#        ['Backtype', 'S08', 'Other SaaS',
#         'BackType is a marketing intelligence platform that helps brands and agencies understand the business impact of social media.',
#         '$5.0m'],
#        ['Echodio', 'W09', 'Entertainment',
#         'Echodio was the easiest way to sync and stream your personal music collection across multiple devices. \r\n      \r\n      Echodio was acquired by RealNetworks in 2009. ',
#         '$5.0m'],
#        ['Project Wedding', 'W06', 'Consumer',
#         'Finding wedding vendors is hard. In 2007, a couple started Project Wedding to tackle this problem and eventually grew it into a',
#         '$4.0m'],
#        ['Heysan', 'W07', 'Entertainment',
#         'Heysan was a mobile community and instant messaging service started in 2007 that quickly grew in popularity and raised seed and venture funding from Y Combinator, Khosla Ventures and Atomico. In May 2009 Heysan was acquired by Good Technology.',
#         '$4.0m'],
#        ['Etacts', 'W10', 'Other SaaS',
#         'Etacts is a CRM tool enabling users to stay in touch with people in their address book.',
#         '$3.0m'],
#        ['Bufferbox', 'S12', 'Consumer',
#         'The future of package delivery. We are building a network of automated self-serve kiosks that allow consumers to receive parcels 24/7 from convenient locations. Say goodbye to failed deliveries!\r\n      \r\n      Acquired by Google 11/30/2012',
#         '$3.0m'],
#        ['Lingt', 'S09', 'Education',
#         'Lingt provided a web-based platform for learning languages leveraging gaming mechanics and spaced repetition.  It was acquired by dictionary.com at the end of 2010.',
#         '$3.0m'],
#        ['reMail', 'W09', 'Other SaaS',
#         'Email search for iPhone. Acquired by Google in Feb 2010.',
#         '$3.0m'],
#        ['Fridge', 'S10', 'Entertainment', 'Disposable social networks.',
#         '$3.0m'],
#        ['TextPayMe', 'S05', 'Fintech',
#         'TextPayMe is an SMS payment service that allows users to send money to others using text messages.',
#         '$3.0m'],
#        ['Fanvibe', 'S10', 'Entertainment',
#         'Fanvibe is a social platform for watching sports and communicating with others who are watching the same game.',
#         '$2.0m'],
#        ['Sendoid', 'W11', 'Other SaaS',
#         'High speed peer to peer data transport technology for consumers (Sendoid) and enterprises (Expresso).',
#         '$2.0m'],
#        ['TapEngage', 'S11', 'Other SaaS',
#         'Tablet ad network, acquired by Dropbox in July 2012', '$2.0m'],
#        ['GazeHawk', 'S10', 'Dev Tools', 'Eyetracking using webcams.',
#         '$2.0m'],
#        ['Bitplay', 'W10', 'Entertainment',
#         'Effortless Video Meetings\r\n      - Acquired by Jive Software in 2013',
#         '$2.0m'],
#        ['Anywhere.FM', 'S07', 'Entertainment',
#         'Anywhere.FM is a music player that enables users to upload music collections and play them anywhere from the web.',
#         '$2.0m'],
#        ['Stypi', 'S11', 'Other SaaS', 'Realtime collaborative coding',
#         '$2.0m'],
#        ['Mattermark', 'S12', 'Other SaaS',
#         'Big Data Meets Startup Investing\r\n      \r\n      The best tool for tracking and benchmarking more than 200,000 startups from around the world.',
#         '$1.0m'],
#        ['Data Marketplace', 'W10', 'Other SaaS',
#         'Data Marketplace is a hub for buying and selling personalized data online.',
#         '$0.6m'],
#        ['VoiceGem', 'S12', 'Other SaaS',
#         'A simple and versatile voice messaging platform. \r\n      \r\n      (Acquired by Palantir - Feb 2013)',
#         '$0.5m'],
#        ['Hackermeter', 'S13', 'Other SaaS',
#         'Replacing resume screening with code challenges.', '$0.4m'],
#        ['Kiko', 'S05', 'Other SaaS',
#         "We're the best online calendar solution to ever exist. Period.",
#         '$0.3m'],
#        ['Slinkset', 'S08', 'Entertainment', 'Votable lists', '$0.1m'],
#        ['GraffitiGeo', 'S09', 'Entertainment',
#         'We let you know where to go and what to get once you get there. (Acquired by Loopt in 2009)',
#         '$0.1m'],
#        ['Picwing', 'S08', 'Entertainment',
#         'Picwing is a photo sharing platform that enables users to share their photos through print and email.',
#         '$0.1m'],
#        ['RethinkDB', 'S09', 'Other SaaS',
#         'The open source database for the realtime web.', '$0.0m']],
#       dtype='<U255')

# %%
datas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-4e980bc0846e> in <module>
# ----> 1 datas
#
# NameError: name 'datas' is not defined

# %%
for i in urls:
    y_combinator_scraper(i)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:01<00:00,  3.84it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:01<00:00,  3.90it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:01<00:00,  3.84it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:01<00:00,  4.19it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:01<00:00,  3.81it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:01<00:00,  3.93it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:01<00:00,  3.98it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:01<00:00,  3.91it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:01<00:00,  4.68it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:01<00:00,  3.94it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:01<00:00,  4.58it/s]
